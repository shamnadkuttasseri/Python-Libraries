# %%
# !pip install seaborn

# %%
import seaborn as sns

# %% [markdown]
# ### Load data to construct seaborn plots

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic', 'anagrams', 'anagrams', 'anscombe', 'anscombe', 'attention', 'attention', 'brain_networks', 'brain_networks', 'car_crashes', 'car_crashes', 'diamonds', 'diamonds', 'dots', 'dots', 'dowjones', 'dowjones', 'exercise', 'exercise', 'flights', 'flights', 'fmri', 'fmri', 'geyser', 'geyser', 'glue', 'glue', 'healthexp', 'healthexp', 'iris', 'iris', 'mpg', 'mpg', 'penguins', 'penguins', 'planets', 'planets', 'seaice', 'seaice', 'taxis', 'taxis', 'tips', 'tips', 'titanic', 'titanic', 'anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
df=sns.load_dataset('car_crashes')
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
import matplotlib.pyplot as plt

# %%
sns.set_theme() #styling using set()
plt.scatter(df.speeding,df.alcohol)
plt.show()

# %%
sns.set_style("white")
plt.subplot(151)
sns.set_style("ticks")
plt.subplot(152)
sns.set_style("dark")
plt.subplot(153)
sns.set_style("whitegrid")
plt.subplot(154)
sns.set_style("darkgrid")
plt.subplot(155)
# Out:
# <Axes: >

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style("white")
sns.despine()
plt.show()

# %% [markdown]
# ### Overriding elements of the seaborn styles

# %%
param=sns.axes_style()
param
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.15',
#  'axes.grid': False,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style("darkgrid",{'gridcolor':'.1'})
sns.despine()
plt.show()

# %% [markdown]
# ### context

# %%
plt.scatter(df.speeding,df.alcohol)
sns.set_style("dark")
sns.set_context("notebook")#paper,talk,poster are also contexts
plt.show()

# %% [markdown]
# ### Seaborn color palette

# %%
sns.palplot(sns.color_palette("gist_heat",10))
plt.show()

# %%
sns.palplot(sns.color_palette("PiYG",10))
plt.show()

# %%
sns.palplot(sns.color_palette("Greens",10))
plt.show()

# %% [markdown]
# ### Relational plots
#
#  1.relplot
#  2.scatterplot
#  3.lineplot

# %% [markdown]
# #### Plotiing with the relplot function

# %%
tips=sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.set_context("notebook")

# %%
sns.relplot(data=tips,x="total_bill",y='tip')
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data=tips,x="total_bill",y='tip',hue="sex")
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data=tips,x="total_bill",y='tip',hue="day",col="sex",col_wrap=2)
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data=tips,x="size",y='tip',kind="line")
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Plotiing with the scatterplot function

# %%
sns.scatterplot(data=tips,x="total_bill",y='tip')
plt.show()

# %% [markdown]
# #### Plotiing with the lineplot function

# %%
sns.lineplot(data=tips,x="total_bill",y='tip')
plt.show()

# %% [markdown]
# ### Categorical data plots
#
# #### barplot

# %%
tips=sns.load_dataset("tips")
sns.barplot(x='day',y='total_bill',data=tips)
plt.show()

# %% [markdown]
# #### countplot()

# %%
sns.countplot(x='day',data=tips)
plt.show()

# %% [markdown]
# #### boxplot and violinplot

# %%
tips=sns.load_dataset("tips")
sns.boxplot(x="day",y="total_bill",data=tips,palette='BuGn')
plt.show()

# %%
tips=sns.load_dataset("tips")
sns.boxplot(data=tips,palette='BuGn',orient="h")
plt.show()

# %%
sns.boxplot(x="day",y="total_bill",hue="sex",data=tips,palette='BuGn')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
tips=sns.load_dataset("tips")
sns.violinplot(x="day",y="total_bill",data=tips,palette='rainbow')
plt.show()

# %%
sns.violinplot(x="day",y="total_bill",hue="smoker",data=tips,palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x="day",y="total_bill",hue="smoker",split=True,data=tips,palette='rainbow')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### stripplot and swarmplot

# %% [markdown]
# #### stripplot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
tips=sns.load_dataset("tips")
sns.stripplot(x="day",y="total_bill",data=tips)
plt.show()

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=False,hue="sex")
plt.show()

# %%
sns.stripplot(x="day",y="total_bill",data=tips,jitter=True,hue="sex")
plt.show()

# %% [markdown]
# #### swarm plot

# %%
tips=sns.load_dataset("tips")
sns.swarmplot(data=tips, x="total_bill")
plt.show()

# %%
sns.swarmplot(data=tips, x="total_bill",y="day")
plt.show()

# %% [markdown]
# ### combine plot(swarm and violin)

# %%
tips=sns.load_dataset("tips")
sns.swarmplot(data=tips, x="total_bill",y="day",color="black",size=3)
sns.violinplot(data=tips, x="total_bill",y="day",palette="rainbow")
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %% [markdown]
# #### point plot()

# %%
tips=sns.load_dataset("tips")
sns.pointplot(x="day",y="tip",data=tips)
plt.show()

# %% [markdown]
# ### Distribution plot

# %% [markdown]
# #### 1. distplot()

# %%
penguins= sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.displot(penguins,x="flipper_length_mm")
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(penguins,x="flipper_length_mm",binwidth=2)
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(penguins,x="flipper_length_mm",hue="species")
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### 2.histplot()

# %%
penguins= sns.load_dataset("penguins")
sns.histplot(penguins,x="flipper_length_mm")
plt.show()

# %%
sns.histplot(penguins,y="flipper_length_mm")
plt.show()

# %% [markdown]
# #### 3.jointplot()
#
#      1.sactter
#      2.reg
#      3.resid
#      4.kde
#      5.hex

# %%
penguins= sns.load_dataset("penguins")
sns.jointplot(penguins,x="bill_length_mm",y="bill_depth_mm")
plt.show()

# %%
sns.jointplot(penguins,x="bill_length_mm",y="bill_depth_mm",kind="kde")
plt.show()

# %%
sns.jointplot(penguins,x="bill_length_mm",y="bill_depth_mm",kind="hex")
plt.show()

# %% [markdown]
# #### 4.Pair Plot

# %%
penguins=sns.load_dataset("penguins")
sns.pairplot(penguins)
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(penguins,hue="island")
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(penguins,kind="kde")
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(penguins,kind="hex")
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### 5.rugplot()

# %%
tips=sns.load_dataset("tips")
sns.kdeplot(data=tips, x="total_bill")
sns.rugplot(data=tips, x="total_bill")
plt.show()

# %%
sns.scatterplot(data=tips, x="total_bill",y="tip")
sns.rugplot(data=tips, x="total_bill",y="tip")
plt.show()

# %%
sns.scatterplot(data=tips, x="total_bill",y="tip",hue="time")
sns.rugplot(data=tips, x="total_bill",y="tip",hue="time")
plt.show()

# %% [markdown]
# #### 6.KDE plot()

# %%
tips=sns.load_dataset("tips")
sns.kdeplot(data=tips,x="total_bill")
plt.show()

# %%
sns.kdeplot(data=tips,x="total_bill",hue="time")
plt.show()

# %%
sns.kdeplot(data=tips,x="total_bill",hue="time",multiple='stack')
plt.show()

# %%
sns.kdeplot(data=tips,x="total_bill",hue="size",
           fill=True,common_norm=False,palette="crest",
           alpha=.5,linewidth=0)
plt.show()

# %% [markdown]
# ### Regression plot()
#
#         1.lmplot
#         2.Regplot

# %% [markdown]
# #### regplot()

# %%
tips=sns.load_dataset("tips")
sns.regplot(x="total_bill" ,y="tip",data=tips)
plt.show()

# %%
sns.regplot(x="size" ,y="total_bill",data=tips,x_jitter=0.8)
plt.show()

# %% [markdown]
# #### lmplot()

# %%
tips=sns.load_dataset("tips")
sns.lmplot(x="total_bill" ,y="tip",data=tips)
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(x="total_bill" ,y="tip",data=tips,col="day",hue="sex",
           col_wrap=2,height=3)
plt.show()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Matrix plots
#
#     1.clustermap
#     2.Heatmap

# %% [markdown]
# #### heat map

# %%
flights=sns.load_dataset("flights")
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights=sns.load_dataset("flights")
flights_pivoted=flights.pivot(index="month",columns="year",values="passengers")

ax=sns.heatmap(flights_pivoted,cmap="YlGnBu")

# %%
ax=sns.heatmap(flights_pivoted,annot=True,fmt="d")

# %%
ax=sns.heatmap(flights_pivoted,cmap="crest",linecolor="white",linewidth=3)

# %% [markdown]
# #### cluster map

# %%
sns.clustermap(flights_pivoted)

# %%
sns.clustermap(flights_pivoted,cmap="coolwarm",standard_scale=1)

# %% [markdown]
# ### Multi-Plot Grid

# %% [markdown]
# #### facetgrid

# %%
tips=sns.load_dataset("tips")
g=sns.FacetGrid(tips,col="sex")
g.map(sns.scatterplot,"total_bill","tip")
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
tips=sns.load_dataset("tips")
g=sns.FacetGrid(tips,col="time",row="sex")
g.map(sns.scatterplot,"total_bill","tip")
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# #### Pair grid

# %%
g=sns.PairGrid(penguins,diag_sharey=False)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot)

# %% [markdown]
# #### Joint Grid

# %%
g=sns.JointGrid(data=penguins,x="bill_length_mm",y="bill_depth_mm")
g.plot(sns.scatterplot,sns.histplot,alpha=.7,edgecolor=".2",linewidth=.5)
